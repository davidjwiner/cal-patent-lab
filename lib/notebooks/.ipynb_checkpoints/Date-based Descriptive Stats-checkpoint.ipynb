# %%
import numpy as np
import pandas as pd
import re
from pandas import DataFrame
from sqlalchemy import create_engine
from matplotlib import pyplot as plt
import matplotlib as mpl
from math import log

# %matplotlib inline

# %%
# Connecting to the db
host_db = "cal-patent-lab.chhaitskv8dz.us-west-2.rds.amazonaws.com"
username = "teamrocket"
password = "teamrocket"
db = "teamrocket"

engine = create_engine("mysql://{}:{}@{}/{}".format(
    username, password, host_db, db))
connection = engine.connect()
q = "select patent_info.patent_id, patent_info.art_unit, datediff(patent_info.issue_date, patent_info.filing_date) as app2grant, datediff(ptab_cases.filing_date, patent_info.issue_date) as grant2challenge, datediff(ptab_cases.decision_date, ptab_cases.filing_date) as challenge2decision, ptab_cases.invalidated, ptab_cases.denied from patent_info, ptab_cases where patent_info.patent_id = ptab_cases.patent_id;"
patent_ptab_df = pd.read_sql(q, engine)
connection.close()

# %%
clean_df = patent_ptab_df.dropna(axis=0, how="any")

# %%
inval = clean_df[clean_df.invalidated == 1]
not_inval = clean_df[clean_df.invalidated == 0]
denied = clean_df[clean_df.denied == 1]
not_denied = clean_df[clean_df.denied == 0]

app2grant_data = {'not_invalidated' : not_inval.app2grant, 'invalidated' : inval.app2grant, "denied" : denied.app2grant, "not_denied" : not_denied.app2grant}
app2grant_df = pd.DataFrame(data=app2grant_data)
print("Application-to-grant time")
print("Means")
print(app2grant_df.mean())
print("Standard deviations")
print(app2grant_df.std())
# Out:
# Application-to-grant time
# Means
# denied             1173.292804
# invalidated        1076.357606
# not_denied         1088.524841
# not_invalidated    1173.913103
# dtype: float64
# Standard deviations
# denied             793.170202
# invalidated        703.324244
# not_denied         704.402981
# not_invalidated    786.261077
# dtype: float64

# %%
print("Distributions of app2grant intervals")
app2grant_df.hist(sharex=True, bins=32, figsize=(12,10))
app2grant_df[app2grant_df < 2000].hist(sharex=True, bins=32, figsize=(12,10))
# Out:
# Distributions of app2grant intervals
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f768d2e54d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f768d159c10>]], dtype=object)

# %%
grant2challenge_data = {'not_invalidated' : not_inval.grant2challenge, 'invalidated' : inval.grant2challenge, "not_denied" : not_denied.grant2challenge, "denied" : denied.grant2challenge}
grant2challenge_df = pd.DataFrame(data=grant2challenge_data)
print("Grant-to-challenge time")
print("Means")
print(grant2challenge_df.mean())
print("Standard deviations")
print(grant2challenge_df.std())
# Out:
# Grant-to-challenge time
# Means
# denied             2413.459057
# invalidated        2452.178082
# not_denied         2411.923567
# not_invalidated    2387.929481
# dtype: float64
# Standard deviations
# denied             1893.444105
# invalidated        1836.010399
# not_denied         1821.659026
# not_invalidated    1878.351489
# dtype: float64

# %%
print("Distributions of grant2challenge intervals")
grant2challenge_df.hist(sharex=True, bins=32, figsize=(12,10))
grant2challenge_df[grant2challenge_df < 2000].hist(sharex=True, bins=32, figsize=(12,10))
# Out:
# Distributions of grant2challenge intervals
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f768c4ff190>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f768cae0e50>]], dtype=object)

# %%
challenge2decision_data = {'not_invalidated' : not_inval.challenge2decision, 'invalidated' : inval.challenge2decision, "not_denied" : not_denied.challenge2decision, "denied" : denied.challenge2decision}
challenge2decision_df = pd.DataFrame(data=challenge2decision_data)
print("Challenge-to-decision time")
print("Means")
print(challenge2decision_df.mean())
print("Standard deviations")
print(challenge2decision_df.std())
# Out:
# Challenge-to-decision time
# Means
# denied             160.298759
# invalidated        177.270368
# not_denied         177.628025
# not_invalidated    161.967243
# dtype: float64
# Standard deviations
# denied             41.613749
# invalidated        28.160763
# not_denied         27.720548
# not_invalidated    40.815713
# dtype: float64

# %%
print("Distributions of challenge2decision intervals")
challenge2decision_df.hist(sharex=True, bins=32, figsize=(12,10))
# Out:
# Distributions of challenge2decision intervals
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f768cdf1bd0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f768c343750>]], dtype=object)

# %%
plt.figure(figsize=(5.1, 4.5), dpi=150)
plt.scatter(app2grant_df.invalidated, grant2challenge_df.invalidated, s=1.9, color="#ff6000")
plt.scatter(app2grant_df.not_invalidated, grant2challenge_df.not_invalidated, s=1.5, color="#156eb1")
plt.xlabel('application-to-grant time (days)')
plt.ylabel('grant-to-challenge time (days)')
ax = plt.gca()
ax.legend(labels=['invalidated', 'not invalidated'])
print("App2grant vs. grant2challenge, invalidated vs. not invalidated")
plt.savefig("./a2g_g2c-inval.png", dpi=250)
# Out:
# App2grant vs. grant2challenge, invalidated vs. not invalidated

# %%
plt.figure(figsize=(5.1, 4.5), dpi=150)
plt.scatter(app2grant_df.denied, grant2challenge_df.denied, s=1.9, color="#ff6000")
plt.scatter(app2grant_df.not_denied, grant2challenge_df.not_denied, s=1.5, color="#156eb1")
plt.xlabel('application-to-grant time (days)')
plt.ylabel('grant-to-challenge time (days)')
ax = plt.gca()
ax.legend(labels=['denied', 'not denied'])
plt.savefig("./a2g-g2c-denied.png", dpi=250)

# %%
plt.figure(figsize=(5.1, 4.5), dpi=150)
plt.scatter(app2grant_df.invalidated, challenge2decision_df.invalidated, s=1.9, color="#ff6000")
plt.scatter(app2grant_df.not_invalidated, challenge2decision_df.not_invalidated, s=1.5, color="#156eb1")
plt.xlabel('application-to-grant time (days)')
plt.ylabel('challenge-to-decision time (days)')
ax = plt.gca()
ax.legend(labels=['invalidated', 'not invalidated'])
print("Application-to-grant vs. challenge-to-decision, invalidated vs. not invalidated")
plt.savefig("./a2g_c2d-inval.png", dpi=250)
# Out:
# Application-to-grant vs. challenge-to-decision, invalidated vs. not invalidated

# %%
plt.figure(figsize=(5.1, 4.5), dpi=150)
plt.scatter(app2grant_df.denied, challenge2decision_df.denied, s=1.9, color="#ff6000")
plt.scatter(app2grant_df.not_denied, challenge2decision_df.not_denied, s=1.5, color="#156eb1")
plt.xlabel('application-to-grant time (days)')
plt.ylabel('challenge-to-decision time (days)')
ax = plt.gca()
ax.legend(labels=['denied', 'not denied'])
print("Application-to-grant vs. challenge-to-decision, denied vs. not denied")
plt.savefig("./a2g_c2d-denied.png", dpi=250)
# Out:
# Application-to-grant vs. challenge-to-decision, denied vs. not denied

# %%
plt.figure(figsize=(5.1, 4.5), dpi=150)
plt.scatter(grant2challenge_df.invalidated, challenge2decision_df.invalidated, s=1.9, color="#ff6000")
plt.scatter(grant2challenge_df.not_invalidated, challenge2decision_df.not_invalidated, s=1.5, color="#156eb1")
plt.xlabel('grant-to-challenge time (days)')
plt.ylabel('challenge-to-decision time (days)')
ax = plt.gca()
ax.legend(labels=['invalidated', 'not invalidated'])
print("Grant-to-challenge vs. challenge-to-decision, invalidated vs. not invalidated")
plt.savefig("./g2c-c2d-inval.png", dpi=250)
# Out:
# Grant-to-challenge vs. challenge-to-decision, invalidated vs. not invalidated

# %%
plt.figure(figsize=(5.1, 4.5), dpi=150)
plt.scatter(grant2challenge_df.denied, challenge2decision_df.denied, s=1.9, color="#ff6000")
plt.scatter(grant2challenge_df.not_denied, challenge2decision_df.not_denied, s=1.5, color="#156eb1")
plt.xlabel('grant-to-challenge time (days)')
plt.ylabel('challenge-to-decision time (days)')
ax = plt.gca()
ax.legend(labels=['denied', 'not denied'])
print("Grant-to-challenge vs. challenge-to-decision, denied vs. not denied")
plt.savefig("./g2c-c2d-denied.png", dpi=250)
# Out:
# Grant-to-challenge vs. challenge-to-decision, denied vs. not denied

# %%
plt.figure(figsize=(5.1, 4.0), dpi=150)
c2d_denied = challenge2decision_df[["denied", "not_denied"]]
c2d_denied.plot.hist(sharex=True, bins=40, alpha=0.6, figsize=(4.5, 4.5))
plt.xlabel("challenge-to-decision time (days)")
plt.savefig("./c2d_denied.png", dpi=200)

# %%
plt.figure(figsize=(5.1, 4.0), dpi=150)
c2d_inval = challenge2decision_df[["invalidated", "not_invalidated"]]
c2d_inval.plot.hist(sharex=True, bins=32, alpha=0.6, figsize=(4.5, 4.5))
plt.xlabel("challenge-to-decision time (days)")
plt.savefig("./c2d_inval.png", dpi=200)

# %%
plt.figure(figsize=(5.1, 4.0), dpi=150)
a2g_denied = app2grant_df[["denied", "not_denied"]]
a2g_denied.plot.hist(sharex=True, bins=32, alpha=0.6, figsize=(4.5, 4.5))
plt.xlabel("application-to-grant time (days)")
plt.savefig("./a2g_denied.png", dpi=200)

# %%
plt.figure(figsize=(5.1, 4.0), dpi=150)
a2g_inval = app2grant_df[["not_invalidated", "invalidated"]]
a2g_inval.plot.hist(sharex=True, bins=32, alpha=0.6, figsize=(4.5, 4.5))
plt.xlabel("application-to-grant time (days)")
plt.savefig("./a2g_inval.png", dpi=200)

# %%
plt.figure(figsize=(5.1, 4.0), dpi=150)
g2c_denied = grant2challenge_df[["denied", "not_denied"]]
g2c_denied.plot.hist(sharex=True, bins=32, alpha=0.6, figsize=(4.5, 4.5))
plt.xlabel("grant-to-challenge time (days)")
plt.savefig("./g2c_denied.png", dpi=200)

# %%
plt.figure(figsize=(5.1, 4.0), dpi=150)
g2c_inval = grant2challenge_df[["not_invalidated", "invalidated"]]
g2c_inval.plot.hist(sharex=True, bins=32, alpha=0.6, figsize=(4.5, 4.5))

plt.xlabel("grant-to-challenge time (days)")
plt.savefig("./g2c_inval.png", dpi=200)
